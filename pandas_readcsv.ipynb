# %%
import pandas as pd
# pd.read_csv('data_file1.csv')
df = pd.read_json('data61.json',orient='records')

# %%
df.head()
# Out:
#   Academic Session:                      School:  Credits:  \
# 0           2020-21   Adam Smith Business School        20
# 1           2020-21   Adam Smith Business School        20
# 2           2020-21   Adam Smith Business School        20
# 3           2020-21   Adam Smith Business School        20
# 4           2020-21   Adam Smith Business School        20
#
#                     Level: Typically Offered: Available to Visiting Students:  \
# 0   Level 1 (SCQF level 7)         Semester 2                              No
# 1   Level 1 (SCQF level 7)         Semester 1                              No
# 2   Level 1 (SCQF level 7)         Semester 2                             Yes
# 3   Level 1 (SCQF level 7)         Semester 1                             Yes
# 4   Level 1 (SCQF level 7)         Semester 1                             Yes
#
#   Available to Erasmus Students:  \
# 0                             No
# 1                             No
# 2                            Yes
# ...

# %%
df[100:120]
# Out:
#     Academic Session:         School:  Credits:                   Level:  \
# 100           2020-21   Short Courses        20   Level 1 (SCQF level 7)
# 101           2020-21   Short Courses        20   Level 1 (SCQF level 7)
# 102           2020-21   Short Courses        20   Level 1 (SCQF level 7)
# 103           2020-21   Short Courses        10   Level 1 (SCQF level 7)
# 104           2020-21   Short Courses         0   Level 1 (SCQF level 7)
# 105           2020-21   Short Courses        10   Level 1 (SCQF level 7)
# 106           2020-21   Short Courses        10   Level 1 (SCQF level 7)
# 107           2020-21   Short Courses        20   Level 1 (SCQF level 7)
# 108           2020-21   Short Courses         0   Level 1 (SCQF level 7)
# 109           2020-21   Short Courses        10   Level 1 (SCQF level 7)
# 110           2020-21   Short Courses        10   Level 1 (SCQF level 7)
# 111           2020-21   Short Courses        10   Level 1 (SCQF level 7)
# ...

# %%
df.to_csv('data_file1.csv')
